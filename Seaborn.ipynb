# %%
##Univariate distribution

##sns.distplot(df['column_name'])
## kde=false

### when we are doing univariate distribution , only 1 column name(feature)
### is specified here

### we consider here only 1 feature that is 1 columns

# %%
## Bivariate distribution

### 2 features 
##sns.jointplot(df[column1], df[column2]); 

### this will work only when both are numerical 
## kind
### kind=hex ## hexbin plot
### kind=kde  ### kernel density estimation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fit=pd.read_csv('https://raw.githubusercontent.com/Pre malatha-success/Statistics/main/CardioGoodFitness-1.csv')

# %%
fit.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
fit.shape
# Out:
# (180, 9)

# %%
fit.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
fit.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
fit.shape
# Out:
# (180, 9)

# %%
fit.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
fit.sample()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 148   TM798   24  Female         16        Single      5        5   52291
#
#      Miles
# 148    200

# %%
fit.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 72    TM195   39    Male         16     Partnered      4        4   59124
# 123   TM498   33  Female         16     Partnered      5        3   53439
# 23    TM195   24  Female         16     Partnered      5        5   44343
# 18    TM195   23  Female         16        Single      4        3   38658
# 118   TM498   32    Male         16        Single      4        3   60261
# 144   TM798   23  Female         18        Single      5        4   53536
# 22    TM195   24  Female         16        Single      4        3   42069
# 84    TM498   21  Female         14     Partnered      5        4   34110
# 139   TM498   48    Male         16     Partnered      2        3   57987
# 100   TM498   25  Female         14     Partnered      5        3   47754
#
#      Miles
# 72     132
# 123     95
# 23     188
# 18     113
# 118    127
# 144    100
# 22      94
# 84     212
# 139     64
# 100    106

# %%
fit.sample(20)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 92    TM498   23  Female         14        Single      3        2   40932
# 111   TM498   27    Male         14        Single      4        2   45480
# 121   TM498   33  Female         16     Partnered      2        3   50028
# 60    TM195   33  Female         16     Partnered      3        3   46617
# 0     TM195   18    Male         14        Single      3        4   29562
# 119   TM498   32    Male         16     Partnered      3        3   53439
# 39    TM195   26    Male         16     Partnered      4        4   44343
# 70    TM195   38    Male         14        Single      2        3   52302
# 17    TM195   23    Male         16     Partnered      4        3   39795
# 8     TM195   21    Male         15        Single      5        4   35247
# 43    TM195   27  Female         14     Partnered      2        3   45480
# 38    TM195   26  Female         16        Single      3        3   36384
# ...

# %%
fit.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
fit.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
fit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
### Plotting univariate distributions
### using seaborn library
## hsitogram only works for numerical data
## univariate distribution uses single variable, i.e single feature
## like age or like education

# %%
## distribution plot

sns.distplot(auto['Age'], color='red');
# Out:
# E:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## distribution plot
### kde is bydefault true
### the curve we see is kde

sns.distplot(auto['Education'], color='green');
# Out:
# E:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## we can mention kde=False so remove the curve shown in above graph

sns.distplot(auto['Education'], kde=False, color= 'red')
# Out:
# E:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Education'>

# %%
### Bivariate distribution
## using 2 features
## joint plot from seaborn
## sns.jointplot( df['column 1'], df['column2'])

# %%
sns.jointplot(fit['Income'], fit['Education'])
# Out:
# E:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(fit['Fitness'], fit['Miles'])
# Out:
# E:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(fit['Fitness'], fit['Miles'] , kind="hex" , color='red')
# Out:
# E:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x=fit['Fitness'], y= fit['Miles'] , kind="kde")

# %% [markdown]
# ## Visualizing pairwise relationships in a data set

# %%
sns.pairplot(fit)

### all the numerical features are plotted against each other

# %%
sns.stripplot(x=fit['Product'], y= fit['Usage'], jitter=True)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Usage'>

# %%
sns.stripplot(x=fit['Product'], y= fit['Income'], jitter=True)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Income'>

# %%
sns.swarmplot(x=fit['Product'], y=fit['Income'])
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Income'>

# %%
sns.boxplot(x=fit['Product'], y=fit['Income'])
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Income'>

# %%
sns.countplot(fit['Product'], hue=fit['Gender']);
# Out:
# E:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fit.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
### count--> total number of observations

### mean --> sum of all observations divided by total number of observations
## if there are outliers, it affects the mean

### std -->
